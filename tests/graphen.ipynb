# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

all = pd.DataFrame(pd.read_excel('sensordata_excel/auslagerungsdatatest.xlsx'))

data = all[['acc.ax','acc.ay','acc.az','acc.gx','acc.gy','acc.gz','gyro.gx','gyro.gy','gyro.gz','timestamp']]
##target = all[['target']]
##target_names = all[['target_names']]

# %%
import seaborn as sns

# %matplotlib inline

sns.pairplot(all, x_vars= ['acc.az', 'acc.gz', 'gyro.gz'], y_vars='timestamp', size = 7, aspect= 0.7)
# Out:
# c:\Users\alexa\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns

# %matplotlib inline

sns.pairplot(all, x_vars= ['acc.ax', 'acc.gx', 'acc.ay', 'acc.gy'], y_vars='timestamp', size = 7, aspect= 0.7)
# Out:
# c:\Users\alexa\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import mpl_toolkits.mplot3d 
import pandas as pd 

X = all['acc.gx'] 
Y = all['acc.gy'] 
Z = all['acc.gz'] 
 
fig = plt.figure() 
fig.set_figwidth(100) 
fig.set_figheight(50) 
ax = fig.add_subplot(111, projection='3d') 

ax.scatter(X, Y, Z, c='red') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\alexa\Documents\bachelorarbeit\graphen.ipynb Zelle 5 in <cell line: 16>()
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/Documents/bachelorarbeit/graphen.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a> ##ax.plot_trisurf(X, Y, Z, color='white', edgecolors='grey', alpha=0.5)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/Documents/bachelorarbeit/graphen.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> ax.scatter(X, Y, Z, c='red')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alexa/Documents/bachelorarbeit/graphen.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> output.set_xlabel('x')                         # axis label
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/Documents/bachelorarbeit/graphen.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> output.set_xlabel('y')
# ...
